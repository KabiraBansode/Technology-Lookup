# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import requests

# %%
df=pd.read_json('https://raw.githubusercontent.com/sahilrahmann/Technology-Lookup-Web-Application/refs/heads/main/technologies.json')
categories=pd.read_json('https://raw.githubusercontent.com/dochne/wappalyzer/refs/heads/main/src/categories.json')

# %%
data=df.copy()

# %%
data
# Out:
#                                                      1C-Bitrix  \
# cats                                                    [1, 6]
# description  1C-Bitrix is a system of web project managemen...
# headers      {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# html         (?:<link[^>]+components/bitrix|(?:src|href)="/...
# icon                                             1C-Bitrix.svg
# implies                                                    PHP
# scripts                                              1c-bitrix
# website                                http://www.1c-bitrix.ru
# cookies                                                    NaN
# js                                                         NaN
# dom                                                        NaN
# pricing                                                    NaN
# saas                                                       NaN
# meta                                                       NaN
# ...

# %% [markdown]
# 1. Manipulate the dataframe in such a way that column becomes row and vica versa

# %%
data=data.transpose()

# %%
data
# Out:
#               cats                                        description  \
# 1C-Bitrix   [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart      [1, 6]                                                NaN
# @sulu/web     [59]                                                NaN
# A-Frame       [25]                                                NaN
# A8.net        [71]          A8.net is an affiliate marketing network.
# ...            ...                                                ...
# wisyCMS        [1]                                                NaN
# wpBakery      [51]  WPBakery is a drag and drop visual page builde...
# wpCache       [23]  WPCache is a static caching plugin for WordPress.
# xCharts       [25]                                                NaN
# xtCommerce     [6]                                                NaN
#
#                                                       headers  \
# 1C-Bitrix   {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1511 entries, 1C-Bitrix to xtCommerce
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cats         1511 non-null   object
#  1   description  776 non-null    object
#  2   headers      320 non-null    object
#  3   html         428 non-null    object
#  4   icon         1474 non-null   object
#  5   implies      482 non-null    object
#  6   scripts      679 non-null    object
#  7   website      1511 non-null   object
#  8   cookies      146 non-null    object
#  9   js           600 non-null    object
#  10  dom          60 non-null     object
#  11  pricing      213 non-null    object
#  12  saas         204 non-null    object
#  13  meta         272 non-null    object
#  14  cpe          195 non-null    object
#  15  certIssuer   5 non-null      object
#  16  url          51 non-null     object
#  17  oss          31 non-null     object
# ...

# %%
data.shape
# Out:
# (1511, 21)

# %%
categories=categories.T
categories.head()
# Out:
#        groups               name priority
# 1         [3]                CMS        1
# 2  [3, 4, 18]     Message boards        1
# 3         [5]  Database managers        2
# 4         [3]      Documentation        2
# 5         [6]            Widgets        9

# %%
# creating the index column in categories.data
categories['index']=np.arange(1,len(categories)+1)
categories.head()
# Out:
#        groups               name priority  index
# 1         [3]                CMS        1      1
# 2  [3, 4, 18]     Message boards        1      2
# 3         [5]  Database managers        2      3
# 4         [3]      Documentation        2      4
# 5         [6]            Widgets        9      5

# %%
for element in data['cats']:
  for i in range(len(element)):
    element[i]=categories.iloc[element[i]-1]['name']

# %%
data['cats']
# Out:
# 1C-Bitrix          [CMS, Ecommerce]
# 3dCart             [CMS, Ecommerce]
# @sulu/web                    [PaaS]
# A-Frame       [JavaScript graphics]
# A8.net                [A/B Testing]
#                       ...
# wisyCMS                       [CMS]
# wpBakery                      [CRM]
# wpCache                   [Caching]
# xCharts       [JavaScript graphics]
# xtCommerce              [Ecommerce]
# Name: cats, Length: 1511, dtype: object

# %%
data.head()
# Out:
#                             cats  \
# 1C-Bitrix       [CMS, Ecommerce]
# 3dCart          [CMS, Ecommerce]
# @sulu/web                 [PaaS]
# A-Frame    [JavaScript graphics]
# A8.net             [A/B Testing]
#
#                                                  description  \
# 1C-Bitrix  1C-Bitrix is a system of web project managemen...
# 3dCart                                                   NaN
# @sulu/web                                                NaN
# A-Frame                                                  NaN
# A8.net             A8.net is an affiliate marketing network.
#
#                                                      headers  \
# 1C-Bitrix  {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                            {'X-Powered-By': '3DCART'}
# @sulu/web                                                NaN
# A-Frame                                                  NaN
# A8.net                                                   NaN
#
# ...

# %%
data['description'].isnull().sum()
# Out:
# 735

# %%
data['headers'].notnull().sum()
# Out:
# 320

# %%
#Counting the value of each keys
# arr=np.array([])
# for element in data['headers'].iloc(0):
#    if isinstance(element,dict):
#       arr=np.append(arr,list(element.keys()))



# Counting the number of valus for each key
# arr=pd.DataFrame(arr)
# arr.value_counts()


#Unique Colums
(arr[0].unique())
# Out:
# 0                Set-Cookie
# 1             X-Powered-CMS
# 2              X-Powered-By
# 3                    Server
# 4          X-AH-Environment
#                ...
# 430                  Server
# 431            X-Powered-By
# 432                  server
# 433    X-Content-Encoded-By
# 434            X-Powered-By
# Name: 0, Length: 435, dtype: object

# %%
print(arr)
# Out:
#                         0
# 0              Set-Cookie
# 1           X-Powered-CMS
# 2            X-Powered-By
# 3                  Server
# 4        X-AH-Environment
# ..                    ...
# 430                Server
# 431          X-Powered-By
# 432                server
# 433  X-Content-Encoded-By
# 434          X-Powered-By
#
# [435 rows x 1 columns]

# %%
# Out:
# 'https+adcashcomscriptpop'
